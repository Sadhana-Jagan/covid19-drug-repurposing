# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN
from sklearn.cluster import SpectralClustering
warnings.filterwarnings('ignore')
from sklearn import metrics

# %%
data_DDR = '/kaggle/input/autoencodersoutput/GAE-128-8-new.csv'
df_ddr = pd.read_csv(data_DDR)

# %% [markdown]
# ## KMeans Clustering

# %%
def load_data(df):
  df2 = df.copy()
  y = df2['Unnamed: 0']
  cols = df2.columns
  ms = MinMaxScaler()
  X = ms.fit_transform(df2)
  X = pd.DataFrame(X, columns=[cols])
  return df2,y,X

def k_means_elbow_method(X,title):
  cs = []
  for i in range(1, 50):
      kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
      kmeans.fit(X)
      cs.append(kmeans.inertia_)
  plt.plot(range(1, 50), cs)
  plt.title('The Elbow Method '+title)
  plt.xlabel('Number of clusters')
  plt.ylabel('CS')
  plt.show()

def k_means_clustering(nclusters,X):
  kmeans = KMeans(n_clusters=nclusters, random_state=0) 
  kmeans.fit(X)
  kmeans.cluster_centers_
  print(kmeans.inertia_)
  return kmeans.labels_

def make_df(labels,y,name):
  df = pd.DataFrame({'node-value':y, 'cluster-label':labels})
  #df['drug'] = df2['nodes']
  df = df.sort_values('cluster-label')
  fileName = '/kaggle/working/HC-128-16' + name
  df.to_csv(fileName)
  return df

# %%
df_ddr,y_ddr,X_ddr = load_data(df_ddr)
k_means_elbow_method(X_ddr,'DDR')

# %%
label_ddr = k_means_clustering(8,X_ddr)
print(metrics.silhouette_score(X_ddr,label_ddr, metric='euclidean'))
# Out:
# 37.870801709289594
# 0.6017813520365695

# %%
df_new_ddr = make_df(label_ddr,y_ddr,'-KM.csv')

# %%
print("DDR")
cm = sns.light_palette("seagreen", as_cmap=True)
df_new_ddr["cluster-label"].value_counts(dropna=False).to_frame().style.background_gradient(cmap=cm)
# Out:
# DDR
# <style type="text/css">
# #T_2ffac_row0_col0 {
#   background-color: #2e8b57;
#   color: #f1f1f1;
# }
# #T_2ffac_row1_col0 {
#   background-color: #bcd9c8;
#   color: #000000;
# }
# #T_2ffac_row2_col0 {
#   background-color: #c7dfd0;
#   color: #000000;
# }
# #T_2ffac_row3_col0 {
#   background-color: #d8e8de;
#   color: #000000;
# }
# #T_2ffac_row4_col0 {
#   background-color: #dfece4;
#   color: #000000;
# }
# #T_2ffac_row5_col0 {
#   background-color: #e6f0e9;
#   color: #000000;
# }
# #T_2ffac_row6_col0 {
#   background-color: #e7f1ea;
#   color: #000000;
# }
# #T_2ffac_row7_col0 {
#   background-color: #ebf3ed;
#   color: #000000;
# }
# </style>
# <table id="T_2ffac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ffac_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster-label</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ffac_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2ffac_row0_col0" class="data row0 col0" >210</td>
#     </tr>
#     <tr>
#       <th id="T_2ffac_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_2ffac_row1_col0" class="data row1 col0" >63</td>
#     </tr>
#     <tr>
#       <th id="T_2ffac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2ffac_row2_col0" class="data row2 col0" >52</td>
#     </tr>
#     <tr>
#       <th id="T_2ffac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2ffac_row3_col0" class="data row3 col0" >34</td>
#     </tr>
#     <tr>
#       <th id="T_2ffac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2ffac_row4_col0" class="data row4 col0" >27</td>
#     </tr>
#     <tr>
#       <th id="T_2ffac_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2ffac_row5_col0" class="data row5 col0" >20</td>
#     </tr>
#     <tr>
#       <th id="T_2ffac_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_2ffac_row6_col0" class="data row6 col0" >18</td>
#     </tr>
#     <tr>
#       <th id="T_2ffac_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_2ffac_row7_col0" class="data row7 col0" >14</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Hierarchial Clustering

# %%
y = df_ddr['Unnamed: 0']
X_ddr_aglo = df_ddr.drop('Unnamed: 0',axis=1)

# %%
import scipy.cluster.hierarchy as sch # importing scipy.cluster.hierarchy for dendrogram
dist_mat = sch.linkage(X_ddr_aglo, method = 'complete',metric='euclidean')
dendrogram = sch.dendrogram(dist_mat) # finding the optimal number of clusters using dendrogram
plt.title('Dendrogram') # title of the dendrogram
plt.xlabel('Drugs') # label of the x-axis
plt.ylabel('Euclidean distances') # label of the y-axis
plt.show() # show the dendrogram

# %%
from sklearn.cluster import AgglomerativeClustering
clustering_model = AgglomerativeClustering(n_clusters=10, affinity='euclidean', linkage='ward')
clustering_model.fit(X_ddr_aglo)
print(metrics.silhouette_score(X_ddr_aglo,clustering_model.labels_, metric='euclidean'))
# Out:
# 0.6454314182773976

# %%
df_agglo = pd.DataFrame({'node-value':y, 'cluster-label':clustering_model.labels_})
df_agglo = df_agglo.sort_values('cluster-label')
fileName = '/kaggle/working/HC-128-16-final-HC.csv'
df_agglo.to_csv(fileName)

# %%
cm = sns.light_palette("seagreen", as_cmap=True)
df_agglo["cluster-label"].value_counts(dropna=False).to_frame().style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_7e8ad_row0_col0 {
#   background-color: #2e8b57;
#   color: #f1f1f1;
# }
# #T_7e8ad_row1_col0 {
#   background-color: #c1dccc;
#   color: #000000;
# }
# #T_7e8ad_row2_col0 {
#   background-color: #d1e4d9;
#   color: #000000;
# }
# #T_7e8ad_row3_col0 {
#   background-color: #d8e8de;
#   color: #000000;
# }
# #T_7e8ad_row4_col0 {
#   background-color: #d9e9df;
#   color: #000000;
# }
# #T_7e8ad_row5_col0 {
#   background-color: #dceae1;
#   color: #000000;
# }
# #T_7e8ad_row6_col0 {
#   background-color: #deece3;
#   color: #000000;
# }
# #T_7e8ad_row7_col0 {
#   background-color: #e1ede5;
#   color: #000000;
# }
# #T_7e8ad_row8_col0 {
#   background-color: #e4efe8;
#   color: #000000;
# }
# #T_7e8ad_row9_col0 {
#   background-color: #ebf3ed;
#   color: #000000;
# }
# </style>
# <table id="T_7e8ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e8ad_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster-label</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e8ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e8ad_row0_col0" class="data row0 col0" >216</td>
#     </tr>
#     <tr>
#       <th id="T_7e8ad_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_7e8ad_row1_col0" class="data row1 col0" >52</td>
#     </tr>
#     <tr>
#       <th id="T_7e8ad_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_7e8ad_row2_col0" class="data row2 col0" >35</td>
#     </tr>
#     <tr>
#       <th id="T_7e8ad_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_7e8ad_row3_col0" class="data row3 col0" >28</td>
#     </tr>
#     <tr>
#       <th id="T_7e8ad_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_7e8ad_row4_col0" class="data row4 col0" >26</td>
#     </tr>
#     <tr>
#       <th id="T_7e8ad_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_7e8ad_row5_col0" class="data row5 col0" >23</td>
#     </tr>
#     <tr>
#       <th id="T_7e8ad_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_7e8ad_row6_col0" class="data row6 col0" >20</td>
#     </tr>
#     <tr>
#       <th id="T_7e8ad_level0_row7" class="row_heading level0 row7" >5</th>
#       <td id="T_7e8ad_row7_col0" class="data row7 col0" >18</td>
#     </tr>
#     <tr>
#       <th id="T_7e8ad_level0_row8" class="row_heading level0 row8" >6</th>
#       <td id="T_7e8ad_row8_col0" class="data row8 col0" >14</td>
#     </tr>
#     <tr>
#       <th id="T_7e8ad_level0_row9" class="row_heading level0 row9" >4</th>
#       <td id="T_7e8ad_row9_col0" class="data row9 col0" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from scipy.spatial.distance import pdist, squareform
import scipy
from scipy.sparse import csgraph
from numpy import linalg as LA
import scipy.cluster.hierarchy as sch
from sklearn import metrics
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import SpectralClustering, AffinityPropagation
warnings.filterwarnings('ignore')

# %%
def getAffinityMatrix(coordinates, k = 10):
    """
    Calculate affinity matrix based on input coordinates matrix and the numeber
    of nearest neighbours.
    
    Apply local scaling based on the k nearest neighbour
        References:
    https://papers.nips.cc/paper/2619-self-tuning-spectral-clustering.pdf
    """
    # calculate euclidian distance matrix
    dists = squareform(pdist(coordinates)) 
    
    # for each row, sort the distances ascendingly and take the index of the 
    #k-th position (nearest neighbour)
    knn_distances = np.sort(dists, axis=0)[k]
    knn_distances = knn_distances[np.newaxis].T
    
    # calculate sigma_i * sigma_j
    local_scale = knn_distances.dot(knn_distances.T)

    affinity_matrix = dists * dists
    affinity_matrix = -affinity_matrix / local_scale
    # divide square distance matrix by local scale
    affinity_matrix[np.where(np.isnan(affinity_matrix))] = 0.0
    # apply exponential
    affinity_matrix = np.exp(affinity_matrix)
    np.fill_diagonal(affinity_matrix, 0)
    return affinity_matrix

def eigenDecomposition(A, plot = True, topK = 5):
    """
    :param A: Affinity matrix
    :param plot: plots the sorted eigen values for visual inspection
    :return A tuple containing:
    - the optimal number of clusters by eigengap heuristic
    - all eigen values
    - all eigen vectors
    
    This method performs the eigen decomposition on a given affinity matrix,
    following the steps recommended in the paper:
    1. Construct the normalized affinity matrix: L = D−1/2ADˆ −1/2.
    2. Find the eigenvalues and their associated eigen vectors
    3. Identify the maximum gap which corresponds to the number of clusters
    by eigengap heuristic
    
    References:
    https://papers.nips.cc/paper/2619-self-tuning-spectral-clustering.pdf
    http://www.kyb.mpg.de/fileadmin/user_upload/files/publications/attachments/Luxburg07_tutorial_4488%5b0%5d.pdf
    """
    L = csgraph.laplacian(A, normed=True)
    n_components = A.shape[0]
    
    # LM parameter : Eigenvalues with largest magnitude (eigs, eigsh), that is, largest eigenvalues in 
    # the euclidean norm of complex numbers.
#     eigenvalues, eigenvectors = eigsh(L, k=n_components, which="LM", sigma=1.0, maxiter=5000)
    eigenvalues, eigenvectors = LA.eig(L)
    
    if plot:
        plt.title('Largest eigen values of input matrix')
        plt.scatter(np.arange(len(eigenvalues)), eigenvalues)
        plt.grid()
        
    # Identify the optimal number of clusters as the index corresponding
    # to the larger gap between eigen values
    index_largest_gap = np.argsort(np.diff(eigenvalues))[::-1][:topK]
    nb_clusters = index_largest_gap + 1
        
    return nb_clusters, eigenvalues, eigenvectors

# %%
y = df_ddr['Unnamed: 0']
X_ddr_aglo = df_ddr.drop('Unnamed: 0',axis=1)

# %%
affinity_matrix_moa = getAffinityMatrix(X_ddr_aglo, k = 7)
k, _,  _ = eigenDecomposition(affinity_matrix_moa)
print(f'Optimal number of clusters {k}')
# Out:
# Optimal number of clusters [ 52  66 126  42 231]

# %%
clustering = SpectralClustering(n_clusters=63, assign_labels="discretize", random_state=0).fit(X_ddr_aglo)
y_pred = clustering.labels_
print('silhouette_score')
print(metrics.silhouette_score(X_ddr_aglo,y_pred, metric='euclidean'))
df_new_ddr = make_df(y_pred,y,'-SC.csv')
# Out:
# silhouette_score
# 0.3997997232400693

# %%
cm = sns.light_palette("seagreen", as_cmap=True)
df_new_ddr["cluster-label"].value_counts(dropna=False).to_frame().style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_7da9f_row0_col0 {
#   background-color: #2e8b57;
#   color: #f1f1f1;
# }
# #T_7da9f_row1_col0 {
#   background-color: #a9ceb9;
#   color: #000000;
# }
# #T_7da9f_row2_col0 {
#   background-color: #bfdbca;
#   color: #000000;
# }
# #T_7da9f_row3_col0 {
#   background-color: #c4ddcf;
#   color: #000000;
# }
# #T_7da9f_row4_col0 {
#   background-color: #c7dfd0;
#   color: #000000;
# }
# #T_7da9f_row5_col0 {
#   background-color: #d1e4d9;
#   color: #000000;
# }
# #T_7da9f_row6_col0 {
#   background-color: #d8e8de;
#   color: #000000;
# }
# #T_7da9f_row7_col0 {
#   background-color: #dceae1;
#   color: #000000;
# }
# #T_7da9f_row8_col0 {
#   background-color: #deece3;
#   color: #000000;
# }
# #T_7da9f_row9_col0 {
#   background-color: #dfece4;
#   color: #000000;
# }
# #T_7da9f_row10_col0 {
#   background-color: #e2eee6;
#   color: #000000;
# }
# #T_7da9f_row11_col0 {
#   background-color: #e3eee7;
#   color: #000000;
# }
# #T_7da9f_row12_col0 {
#   background-color: #e7f0ea;
#   color: #000000;
# }
# #T_7da9f_row13_col0 {
#   background-color: #e8f1eb;
#   color: #000000;
# }
# #T_7da9f_row14_col0, #T_7da9f_row15_col0, #T_7da9f_row16_col0, #T_7da9f_row17_col0 {
#   background-color: #e9f1eb;
#   color: #000000;
# }
# #T_7da9f_row18_col0 {
#   background-color: #ebf3ed;
#   color: #000000;
# }
# </style>
# <table id="T_7da9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7da9f_level0_col0" class="col_heading level0 col0" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cluster-label</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7da9f_level0_row0" class="row_heading level0 row0" >53</th>
#       <td id="T_7da9f_row0_col0" class="data row0 col0" >161</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row1" class="row_heading level0 row1" >45</th>
#       <td id="T_7da9f_row1_col0" class="data row1 col0" >57</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row2" class="row_heading level0 row2" >25</th>
#       <td id="T_7da9f_row2_col0" class="data row2 col0" >38</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row3" class="row_heading level0 row3" >40</th>
#       <td id="T_7da9f_row3_col0" class="data row3 col0" >34</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_7da9f_row4_col0" class="data row4 col0" >32</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row5" class="row_heading level0 row5" >13</th>
#       <td id="T_7da9f_row5_col0" class="data row5 col0" >23</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row6" class="row_heading level0 row6" >1</th>
#       <td id="T_7da9f_row6_col0" class="data row6 col0" >17</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row7" class="row_heading level0 row7" >20</th>
#       <td id="T_7da9f_row7_col0" class="data row7 col0" >14</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row8" class="row_heading level0 row8" >0</th>
#       <td id="T_7da9f_row8_col0" class="data row8 col0" >12</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row9" class="row_heading level0 row9" >21</th>
#       <td id="T_7da9f_row9_col0" class="data row9 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row10" class="row_heading level0 row10" >46</th>
#       <td id="T_7da9f_row10_col0" class="data row10 col0" >9</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row11" class="row_heading level0 row11" >14</th>
#       <td id="T_7da9f_row11_col0" class="data row11 col0" >8</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row12" class="row_heading level0 row12" >7</th>
#       <td id="T_7da9f_row12_col0" class="data row12 col0" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row13" class="row_heading level0 row13" >16</th>
#       <td id="T_7da9f_row13_col0" class="data row13 col0" >4</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row14" class="row_heading level0 row14" >2</th>
#       <td id="T_7da9f_row14_col0" class="data row14 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row15" class="row_heading level0 row15" >8</th>
#       <td id="T_7da9f_row15_col0" class="data row15 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row16" class="row_heading level0 row16" >12</th>
#       <td id="T_7da9f_row16_col0" class="data row16 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row17" class="row_heading level0 row17" >22</th>
#       <td id="T_7da9f_row17_col0" class="data row17 col0" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7da9f_level0_row18" class="row_heading level0 row18" >4</th>
#       <td id="T_7da9f_row18_col0" class="data row18 col0" >1</td>
#     </tr>
#   </tbody>
# </table>
